# %% [markdown]
# <a href="https://colab.research.google.com/github/ganesh12112/ganesh12112/blob/main/Data_analytics_projects_practice_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# UBER TRIPS ANALYSIS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("/content/uber.csv")
data["Date/Time"] = data["Date/Time"].map(pd.to_datetime)
data.head()
# Out:
#             Date/Time      Lat      Lon    Base
# 0 2014-09-01 00:01:00  40.2201 -74.0021  B02512
# 1 2014-09-01 00:01:00  40.7500 -74.0027  B02512
# 2 2014-09-01 00:03:00  40.7559 -73.9864  B02512
# 3 2014-09-01 00:06:00  40.7450 -73.9889  B02512
# 4 2014-09-01 00:11:00  40.8145 -73.9444  B02512
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Lat'].plot(kind='hist', bins=20, title='Lat')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Lon'].plot(kind='hist', bins=20, title='Lon')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
data['Day'] = data["Date/Time"].apply(lambda  x:x.day)
data['weekend'] = data['Date/Time'].apply(lambda x:x.weekday())
data['Hour'] = data['Date/Time'].apply(lambda x:x.hour)
print(data.head())
# Out:
#             Date/Time      Lat      Lon    Base  Day  weekend  Hour
# 0 2014-09-01 00:01:00  40.2201 -74.0021  B02512    1        0     0
# 1 2014-09-01 00:01:00  40.7500 -74.0027  B02512    1        0     0
# 2 2014-09-01 00:03:00  40.7559 -73.9864  B02512    1        0     0
# 3 2014-09-01 00:06:00  40.7450 -73.9889  B02512    1        0     0
# 4 2014-09-01 00:11:00  40.8145 -73.9444  B02512    1        0     0

# %%
sns.set(rc={'figure.figsize':(12,10)})
sns.distplot(data["Day"])
# Out:
# <ipython-input-4-18583bdb7666>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Day"])
# <Axes: xlabel='Day', ylabel='Density'>

# %%
sns.distplot(data["Hour"])
# Out:
# <ipython-input-5-fe964bdaceca>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Hour"])
# <Axes: xlabel='Hour', ylabel='Density'>

# %%
sns.distplot(data["weekend"])
# Out:
# <ipython-input-9-f4de69959004>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["weekend"])
# <Axes: xlabel='weekend', ylabel='Density'>

# %%
# correlation of weekday and hour
df = data.groupby(["weekend","Hour"]).apply(lambda x: len(x))
df = df.unstack()
sns.heatmap(df,annot = False)
# Out:
# <Axes: xlabel='Hour', ylabel='weekend'>

# %% [markdown]
# As we are having the data about longitude and latitude so we can also plot the density of Uber trips according to the regions of the New Your city:

# %%
data.plot(kind = 'scatter',x = 'Lon',y = 'Lat',alpha = 0.4,s = data['Day'],label = 'Uber Trips',
          figsize = (12,8),cmap = plt.get_cmap('jet'))
plt.title("uber Trips Analysis")
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py:1259: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# # my own projects on sales of grocery of food items

# %%
# loading a simple delimited data file
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/Train.csv")
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
print(df.head())
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# colums
print(df.columns)
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB
# None

# %%
# get the item type and save it in to own variable
Item_Type_df = df['Item_Type']

# %%
print(Item_Type_df.head())
# Out:
# 0                    Dairy
# 1              Soft Drinks
# 2                     Meat
# 3    Fruits and Vegetables
# 4                Household
# Name: Item_Type, dtype: object

# %%
print(Item_Type_df.tail())
# Out:
# 8518           Snack Foods
# 8519          Baking Goods
# 8520    Health and Hygiene
# 8521           Snack Foods
# 8522           Soft Drinks
# Name: Item_Type, dtype: object

# %%
# looking at Item_Type ,Item_MRP and Item_Fat_content
# creating the subset
subset = df[['Item_Type','Item_MRP','Item_Fat_Content']]
print(subset.head())
# Out:
#                Item_Type  Item_MRP Item_Fat_Content
# 0                  Dairy  249.8092          Low Fat
# 1            Soft Drinks   48.2692          Regular
# 2                   Meat  141.6180          Low Fat
# 3  Fruits and Vegetables  182.0950          Regular
# 4              Household   53.8614          Low Fat

# %%
print(subset.tail())
# Out:
#                Item_Type  Item_MRP Item_Fat_Content
# 8518         Snack Foods  214.5218          Low Fat
# 8519        Baking Goods  108.1570          Regular
# 8520  Health and Hygiene   85.1224          Low Fat
# 8521         Snack Foods  103.1332          Regular
# 8522         Soft Drinks   75.4670          Low Fat

# %%
# subsetting rows by index label :loc
print(df.head())
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# get the first row
print(df.loc[1])
# Out:
# Item_Identifier                          DRC01
# Item_Weight                               5.92
# Item_Fat_Content                       Regular
# Item_Visibility                       0.019278
# Item_Type                          Soft Drinks
# Item_MRP                               48.2692
# Outlet_Identifier                       OUT018
# Outlet_Establishment_Year                 2009
# Outlet_Size                             Medium
# Outlet_Location_Type                    Tier 3
# Outlet_Type                  Supermarket Type2
# Item_Outlet_Sales                     443.4228
# Name: 1, dtype: object

# %%
# 100th row
print(df.loc[99])
# Out:
# Item_Identifier                              FDB56
# Item_Weight                                   8.75
# Item_Fat_Content                           Regular
# Item_Visibility                           0.074627
# Item_Type                    Fruits and Vegetables
# Item_MRP                                  187.8556
# Outlet_Identifier                           OUT046
# Outlet_Establishment_Year                     1997
# Outlet_Size                                  Small
# Outlet_Location_Type                        Tier 1
# Outlet_Type                      Supermarket Type1
# Item_Outlet_Sales                        1314.2892
# Name: 99, dtype: object

# %%
# get the last row
print(df.tail(n =1))
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8522           DRG01         14.8          Low Fat         0.044878
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 8522  Soft Drinks    75.467            OUT046                       1997
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 8522       Small               Tier 1  Supermarket Type1             765.67

# %%
# subsetting Multiple Rows
# select the first ,100th and 1000 th rows
print(df.loc[[0,99,999]])
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0             FDA15         9.30          Low Fat         0.016047
# 99            FDB56         8.75          Regular         0.074627
# 999           NCP06          NaN          Low Fat         0.039056
#
#                  Item_Type  Item_MRP Outlet_Identifier  \
# 0                    Dairy  249.8092            OUT049
# 99   Fruits and Vegetables  187.8556            OUT046
# 999              Household  152.3366            OUT027
#
#      Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                         1999      Medium               Tier 1
# 99                        1997       Small               Tier 1
# 999                       1985      Medium               Tier 3
#
#            Outlet_Type  Item_Outlet_Sales
# 0    Supermarket Type1          3735.1380
# 99   Supermarket Type1          1314.2892
# 999  Supermarket Type3          2115.9124

# %%
# subset rows by row number : iloc
print(df.iloc[1][1])
# Out:
# 5.92

# %%
print(df.iloc[99])
# Out:
# Item_Identifier                              FDB56
# Item_Weight                                   8.75
# Item_Fat_Content                           Regular
# Item_Visibility                           0.074627
# Item_Type                    Fruits and Vegetables
# Item_MRP                                  187.8556
# Outlet_Identifier                           OUT046
# Outlet_Establishment_Year                     1997
# Outlet_Size                                  Small
# Outlet_Location_Type                        Tier 1
# Outlet_Type                      Supermarket Type1
# Item_Outlet_Sales                        1314.2892
# Name: 99, dtype: object

# %%
print(df.iloc[-1])
# Out:
# Item_Identifier                          DRG01
# Item_Weight                               14.8
# Item_Fat_Content                       Low Fat
# Item_Visibility                       0.044878
# Item_Type                          Soft Drinks
# Item_MRP                                75.467
# Outlet_Identifier                       OUT046
# Outlet_Establishment_Year                 1997
# Outlet_Size                              Small
# Outlet_Location_Type                    Tier 1
# Outlet_Type                  Supermarket Type1
# Item_Outlet_Sales                       765.67
# Name: 8522, dtype: object

# %%
#
print(df.iloc[[0,99,999]])
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0             FDA15         9.30          Low Fat         0.016047
# 99            FDB56         8.75          Regular         0.074627
# 999           NCP06          NaN          Low Fat         0.039056
#
#                  Item_Type  Item_MRP Outlet_Identifier  \
# 0                    Dairy  249.8092            OUT049
# 99   Fruits and Vegetables  187.8556            OUT046
# 999              Household  152.3366            OUT027
#
#      Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                         1999      Medium               Tier 1
# 99                        1997       Small               Tier 1
# 999                       1985      Medium               Tier 3
#
#            Outlet_Type  Item_Outlet_Sales
# 0    Supermarket Type1          3735.1380
# 99   Supermarket Type1          1314.2892
# 999  Supermarket Type3          2115.9124

# %%
#subset the columns
subset = df.loc[:,['Outlet_Type','Outlet_Establishment_Year']]
print(subset.head())
# Out:
#          Outlet_Type  Outlet_Establishment_Year
# 0  Supermarket Type1                       1999
# 1  Supermarket Type2                       2009
# 2  Supermarket Type1                       1999
# 3      Grocery Store                       1998
# 4  Supermarket Type1                       1987

# %%
# subset columns with iloc
# iloc will allow us to use integers
# -1 will select the last column
subset = df.iloc[:,[2,4,-1]]
print(subset.head())
# Out:
#   Item_Fat_Content              Item_Type  Item_Outlet_Sales
# 0          Low Fat                  Dairy          3735.1380
# 1          Regular            Soft Drinks           443.4228
# 2          Low Fat                   Meat          2097.2700
# 3          Regular  Fruits and Vegetables           732.3800
# 4          Low Fat              Household           994.7052

# %%
# subsetting columns by range
small_range = list(range(5))
print(small_range)
# Out:
# [0, 1, 2, 3, 4]

# %%
# subset the datframe with the range
subset = df.iloc[:,small_range]
print(subset.head())
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type
# 0                  Dairy
# 1            Soft Drinks
# 2                   Meat
# 3  Fruits and Vegetables
# 4              Household

# %%
# subsetting rows and columns
# using loc
print(df.loc[42,'Item_Type'])
# Out:
# Snack Foods

# %%
# using iloc # we can acess element by their specific index positioning
# and in loc it is not possible
print(df.iloc[42,1])
# Out:
# 13.6

# %%
# subsetting multiple rows and columns
# get the 1st,100th and 1000th rows
# from 1st,4th and 6th columns
print(df.iloc[[0,99,999],[0,3,5]])
# Out:
#     Item_Identifier  Item_Visibility  Item_MRP
# 0             FDA15         0.016047  249.8092
# 99            FDB56         0.074627  187.8556
# 999           NCP06         0.039056  152.3366

# %% [markdown]
# • if we use the column names directly,
# # it makes the code a bit easier to read
# # note now we have to use loc, instead of iloc

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
print(df.loc[[0,99,999],['Item_Fat_Content','Item_MRP','Item_Outlet_Sales']])
# Out:
#     Item_Fat_Content  Item_MRP  Item_Outlet_Sales
# 0            Low Fat  249.8092          3735.1380
# 99           Regular  187.8556          1314.2892
# 999          Low Fat  152.3366          2115.9124

# %%
print(df.loc[7:15,['Item_Fat_Content','Item_MRP','Item_Outlet_Sales']])
# Out:
#    Item_Fat_Content  Item_MRP  Item_Outlet_Sales
# 7           Low Fat  107.7622          4022.7636
# 8           Regular   96.9726          1076.5986
# 9           Regular  187.8214          4710.5350
# 10          Low Fat   45.5402          1516.0266
# 11          Regular  144.1102          2187.1530
# 12          Regular  145.4786          1589.2646
# 13          Regular  119.6782          2145.2076
# 14          Low Fat  196.4426          1977.4260
# 15          Regular   56.3614          1547.3192

# %%
#
print(df.head(n= 10))
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
# Grouped Means # what is the use of groupby()
# for item type - mean item MRP is calculated
print(df.groupby('Item_Type')['Item_MRP'].mean())
# Out:
# Item_Type
# Baking Goods             126.380766
# Breads                   140.952669
# Breakfast                141.788151
# Canned                   139.763832
# Dairy                    148.499208
# Frozen Foods             138.503366
# Fruits and Vegetables    144.581235
# Hard Drinks              137.077928
# Health and Hygiene       130.818921
# Household                149.424753
# Meat                     139.882032
# Others                   132.851430
# Seafood                  141.841719
# Snack Foods              146.194934
# Soft Drinks              131.492506
# Starchy Foods            147.838023
# Name: Item_MRP, dtype: float64

# %%
# multi_group_var
multi_group_var = df.groupby(['Outlet_Establishment_Year','Outlet_Location_Type'])\
             [['Item_MRP','Item_Weight']].mean()
print(multi_group_var)
# Out:
#                                                   Item_MRP  Item_Weight
# Outlet_Establishment_Year Outlet_Location_Type
# 1985                      Tier 1                139.787088          NaN
#                           Tier 3                139.801791          NaN
# 1987                      Tier 3                141.425982    13.006148
# 1997                      Tier 1                142.057387    12.866801
# 1998                      Tier 3                140.777594    12.913153
# 1999                      Tier 1                140.297699    12.917446
# 2002                      Tier 2                140.950246    12.649989
# 2004                      Tier 2                143.122481    12.829349
# 2007                      Tier 2                139.421119    12.826668
# 2009                      Tier 3                141.678634    12.873346

# %%
# if you need to "flatten" the dataframe ,you can use reset_index method
flat = multi_group_var.reset_index()
print(flat.head(11))
# Out:
#    Outlet_Establishment_Year Outlet_Location_Type    Item_MRP  Item_Weight
# 0                       1985               Tier 1  139.787088          NaN
# 1                       1985               Tier 3  139.801791          NaN
# 2                       1987               Tier 3  141.425982    13.006148
# 3                       1997               Tier 1  142.057387    12.866801
# 4                       1998               Tier 3  140.777594    12.913153
# 5                       1999               Tier 1  140.297699    12.917446
# 6                       2002               Tier 2  140.950246    12.649989
# 7                       2004               Tier 2  143.122481    12.829349
# 8                       2007               Tier 2  139.421119    12.826668
# 9                       2009               Tier 3  141.678634    12.873346

# %%
# grouped frequency counts
# use the nunique to get counts of unique values on a pandas Series
print(df.groupby('Item_Type')['Item_MRP'].nunique())
# Out:
# Item_Type
# Baking Goods              602
# Breads                    226
# Breakfast                 104
# Canned                    598
# Dairy                     625
# Frozen Foods              780
# Fruits and Vegetables    1110
# Hard Drinks               206
# Health and Hygiene        475
# Household                 846
# Meat                      377
# Others                    160
# Seafood                    61
# Snack Foods              1079
# Soft Drinks               418
# Starchy Foods             141
# Name: Item_MRP, dtype: int64

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
# Basic plot
Item_Outlet_Sales_wrt_Outlet_Establishment_Year = df.groupby('Outlet_Establishment_Year')['Item_Outlet_Sales'].mean()
print(Item_Outlet_Sales_wrt_Outlet_Establishment_Year )
# Out:
# Outlet_Establishment_Year
# 1985    2483.677474
# 1987    2298.995256
# 1997    2277.844267
# 1998     339.351662
# 1999    2348.354635
# 2002    2192.384798
# 2004    2438.841866
# 2007    2340.675263
# 2009    1995.498739
# Name: Item_Outlet_Sales, dtype: float64

# %%
Item_Outlet_Sales_wrt_Outlet_Establishment_Year.plot()
# Out:
# <Axes: xlabel='Outlet_Establishment_Year'>
